# %% [markdown]
# ## Displaying images

# %%
from IPython.display import Image
Image(filename='images/image_1.jpg', width=400)

# %%
Image(filename='images/image_2.jpg', width=400)

# %%
from PIL import Image as pili, ImageOps as piliops

imageLocation = "images/" #image directory
borderLocation = "images/borders/" #folder location of border images

dialogueLocation = "images/dialogues/" #dialogue location for english
hindiDialogues = 'images/hindiDialogues/' #dialogue location for hindi

randomHorizontal = "images/randomHorizontal/" #random Horizontal collage location for english
randomVertical = "images/randomVertical/" #random Vertical collage location for english

randomHindiHorizontal = "images/randomHindiHorizontal/" #random Horizontal collage location for hindi
randomHindiVertical = "images/randomHindiVertical/" #random Vertical collage location for hindi

imageName = [0] #naming all images, first value giver for easy understanding

for i in range(1,74): #running loop for number of images
    imageName.append("image_" + str(i)+ ".jpg")
print(imageName[1]) #verifying image name
print(len(imageName)-1) #verifying number of image names
# Out:
# image_1.jpg
# 73

# %% [markdown]
# Creating Borders

# %%
for i in range(1, 74): #creating borders
    piliops.expand(pili.open(imageLocation + imageName[i]), border=(25,40),fill='black').save(borderLocation + imageName[i])

# %%
Image(filename= borderLocation + imageName[1], width=400)

# %%
Image(filename="images/borders/image_1.jpg", width=400)

# %% [markdown]
# Reading dialogue csv file

# %%
import pandas as pd
data = pd.read_csv('mydialog.csv')
data.head(10)
# Out:
#                            dialogs    Images                Hindi dialogues
# 0                                        NaN                            NaN
# 1      *Light Yagami in the class*   image_1      *कक्षा में प्रकाश यागामी*
# 2  *death note falls from the sky*   image_2    *मौत नोट आसमान से गिरती है*
# 3                 *suspense music*   image_3                *सस्पेंस संगीत*
# 4                                    image_4
# 5                                    image_5
# 6                                    image_6
# 7                      Death note?   image_7                       डेथ नोट?
# 8       As in a notebook of death?   image_8       मृत्यु की एक नोटबुक में?
# 9             Hmm.. How to use it:   image_9  हम्म .. इसका उपयोग कैसे करें:

# %%
print(data.shape) #dimension of dialogue file
print(data.values[2][0]) #verifying English Dialogue
print(data.values[2][2]) #verifying Hindi Dialogue
# Out:
# (76, 3)
# *death note falls from the sky*
# *मौत नोट आसमान से गिरती है*

# %% [markdown]
# Creating ENGLISH Dialogues on images

# %%
from PIL import Image as pili, ImageDraw as pild, ImageFont as pilf 

TINT_COLOR = (0, 0, 0)  # Black color on subtitle rectangle

TRANSPARENCY = .25  # Degree of transparency, 0-100%
OPACITY = int(255 * TRANSPARENCY)

for i in range(1,74): #loop running for number of images and creating subtitle for all of them
    from PIL import Image, ImageFont, ImageDraw
    img = pili.open(borderLocation + imageName[i]).convert('RGBA')
    overlay = pili.new('RGBA', img.size, (TINT_COLOR+(0,)))
    draw = pild.Draw(overlay)
    font = pilf.truetype("arial.ttf", 35) #for english font 
    text = data.values[i][0]
    w, h = font.getsize(text)
    num_lines = len(text.split('\n')) #splitting subtitles
    print(num_lines, w, h, i) #printing no.of subtitle lines, width, height, no.of image
    x, y = 25, img.height - (num_lines-0.1*num_lines)*h
    draw.rectangle((x, y-15, x + img.width - 50, y + (num_lines-0.1*num_lines)*h), fill=TINT_COLOR+(OPACITY,)) #drawing subtitle box
    draw.text((x+35, y-15), text, fill=(209, 239, 8), font=font) #writing texts
    img = pili.alpha_composite(img, overlay)
    img = img.convert("RGB") # Remove alpha for saving in jpg format.
    img.save(dialogueLocation + imageName[i]) #saving english image
# Out:
# 1 416 39 1
# 1 466 39 2
# 1 279 39 3
# 1 20 32 4
# 1 30 32 5
# 1 20 32 6
# 1 188 32 7
# 1 423 32 8
# 1 325 32 9
# 2 940 32 10
# 1 341 39 11
# 1 231 32 12
# 2 841 39 13
# 1 428 32 14
# 1 513 32 15
# 1 164 39 16
# 1 224 32 17
# 1 628 39 18
# 1 294 32 19
# 1 622 32 20
# 2 923 39 21
# 2 985 39 22
# 2 1149 39 23
# 2 1110 39 24
# 2 1425 39 25
# 2 1520 39 26
# 1 508 39 27
# 1 272 39 28
# 1 128 32 29
# 1 621 39 30
# 1 485 39 31
# 1 73 39 32
# 1 20 32 33
# 1 30 32 34
# 1 30 32 35
# 1 30 32 36
# 1 30 32 37
# 2 1223 39 38
# 1 583 39 39
# 2 1245 39 40
# 1 584 39 41
# 1 740 39 42
# 2 1625 39 43
# 1 701 39 44
# 1 587 39 45
# 1 246 32 46
# 1 228 32 47
# 1 600 39 48
# 1 151 32 49
# 1 795 39 50
# 1 337 39 51
# 1 491 39 52
# 1 20 32 53
# 1 581 32 54
# 1 556 39 55
# 1 543 39 56
# 1 716 32 57
# 2 1010 39 58
# 2 1258 39 59
# 1 678 37 60
# 2 1193 39 61
# 1 101 32 62
# 2 1286 39 63
# 1 30 32 64
# 1 30 32 65
# 1 30 32 66
# 1 372 39 67
# 1 259 32 68
# 1 452 32 69
# 1 434 39 70
# 1 560 39 71
# 1 461 32 72
# ...

# %% [markdown]
# Creating HINDI Dialogues

# %%
from PIL import Image as pili, ImageDraw as pild, ImageFont as pilf 

TINT_COLOR = (0, 0, 0)  # Black

TRANSPARENCY = .25  # Degree of transparency, 0-100%
OPACITY = int(255 * TRANSPARENCY)

for i in range(1,74): #loop running for number of images and creating subtitle for all of them
    from PIL import Image, ImageFont, ImageDraw
    img = pili.open(borderLocation + imageName[i]).convert('RGBA')
    overlay = pili.new('RGBA', img.size, (TINT_COLOR+(0,)))
    draw = pild.Draw(overlay)
    font = pilf.truetype("c:/windows/fonts/nirmalas.ttf", 35) #for hindi font 
    text = data.values[i][2]
    w, h = font.getsize(text)
    num_lines = len(text.split('\n')) #splitting subtitles
    print(num_lines, w, h, i) #printing no.of subtitle lines, width, height, no.of image
    x, y = 25, img.height - (num_lines-0.1*num_lines)*h
    draw.rectangle((x, y-15, x + img.width - 50, y + (num_lines-0.1*num_lines)*h), fill=TINT_COLOR+(OPACITY,)) #drawing subtitle box
    draw.text((x+35, y-15), text, fill=(209, 239, 8), font=font) #writing texts
    img = pili.alpha_composite(img, overlay)
    img = img.convert("RGB") # Remove alpha for saving in jpg format.
    img.save(hindiDialogues + imageName[i]) #saving hindi image
# Out:
# 1 362 46 1
# 1 414 43 2
# 1 206 46 3
# 1 30 38 4
# 1 30 38 5
# 1 30 38 6
# 1 121 38 7
# 1 329 47 8
# 1 418 46 9
# 3 805 43 10
# 1 375 47 11
# 1 218 47 12
# 3 780 47 13
# 1 285 43 14
# 1 355 43 15
# 1 161 38 16
# 1 176 46 17
# 1 407 47 18
# 1 538 43 19
# 1 582 43 20
# 2 804 46 21
# 2 850 46 22
# 2 904 47 23
# 2 1015 46 24
# 2 1366 47 25
# 2 1558 47 26
# 1 524 47 27
# 1 207 47 28
# 1 102 46 29
# 1 796 47 30
# 1 393 46 31
# 1 65 43 32
# 1 30 38 33
# 1 30 38 34
# 1 30 38 35
# 1 30 38 36
# 1 30 38 37
# 2 1044 47 38
# 1 502 47 39
# 2 995 43 40
# 1 588 43 41
# 1 679 46 42
# 2 1486 47 43
# 1 525 47 44
# 1 457 46 45
# 1 110 47 46
# 1 238 46 47
# 1 488 46 48
# 1 141 43 49
# 1 641 47 50
# 1 270 46 51
# 1 621 46 52
# 1 30 38 53
# 1 588 47 54
# 1 640 47 55
# 1 392 47 56
# 1 681 46 57
# 2 797 43 58
# 2 1189 46 59
# 1 551 47 60
# 2 973 47 61
# 1 69 38 62
# 2 830 47 63
# 1 30 38 64
# 1 30 38 65
# 1 30 38 66
# 1 370 47 67
# 1 169 43 68
# 1 296 43 69
# 1 444 43 70
# 1 524 43 71
# 1 631 47 72
# ...

# %%
from IPython.display import Image #looking the created image
Image(filename=dialogueLocation + imageName[9], width=400)

# %%
from IPython.display import Image #looking the created image
Image(filename=hindiDialogues + imageName[9], width=400)

# %% [markdown]
# ## Horizontal strip

# %%
engList = [0] #creating only image paths list
hindiList = [0] #creating only image paths list
for i in range(1,74):
    engList.append(dialogueLocation + imageName[i])
    hindiList.append(hindiDialogues + imageName[i])

# %%
print(hindiList[1])
print(engList[73])
print(dialogueLocation + imageName[1])
#print(horizontalLocation + imageName[i])
# Out:
# images/hindiDialogues/image_1.jpg
# images/dialogues/image_73.jpg
# images/dialogues/image_1.jpg

# %% [markdown]
# Creating random english Horizontal and vertical stripes

# %%
import numpy as np
import PIL
from os import listdir
from os.path import isfile, join

mypath = dialogueLocation
#onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
onlyfiles = []
verticalImage = []
imageCount = []
for i in range(1,74):
    onlyfiles.append(engList[i])
i, j = 1, 1
while len(onlyfiles) > 0:
    lines = 0
    print("new page!")
    num_cols = old_num_cols = 0
    print(len(onlyfiles))
    
    while lines < 6 and 0 < len(onlyfiles):
        lines += 1
        while num_cols == old_num_cols:
            num_cols = np.random.randint(3, 6)
        old_num_cols = num_cols
        list_im = onlyfiles[:num_cols]
        imgs = [ PIL.Image.open(k) for k in list_im ]
        
        # pick the image which is the smallest, and resize the others to match it (can be arbitrary image shape here)
        min_shape = sorted( [(np.sum(k.size), k.size ) for k in imgs])[0][1]
        imgs_comb = np.hstack( (np.asarray( k.resize(min_shape) ) for k in imgs ) )
        
        # save that beautiful picture
        imgs_comb = PIL.Image.fromarray( imgs_comb)
        imgs_comb.save( randomHorizontal + imageName[i] ) 
        
        verticalImage.append(randomHorizontal + imageName[i])
        
        #print(window)   
        onlyfiles = onlyfiles[num_cols:]    
        i = i+1
        
    imgs = [ PIL.Image.open(i) for i in verticalImage ]

    # pick the image which is the largest, and resize the others to match it 
    min_shape = sorted( [(np.sum(k.size), k.size ) for k in imgs], reverse = 1)[0][1]
    imgs_comb = np.vstack( (np.asarray( k.resize(min_shape) ) for k in imgs ) )

    # save that beautiful picture
    imgs_comb = PIL.Image.fromarray( imgs_comb)
    imgs_comb.save( randomVertical + imageName[j], width=650, height=1300 )
    imageCount.append(randomVertical + imageName[j])
    j += 1
    verticalImage = verticalImage[len(verticalImage):]
    
print(imageCount)
# Out:
# new page!
# 73
# <ipython-input-16-f23f2e952a0f>:30: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   imgs_comb = np.hstack( (np.asarray( k.resize(min_shape) ) for k in imgs ) )
# <ipython-input-16-f23f2e952a0f>:46: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   imgs_comb = np.vstack( (np.asarray( k.resize(min_shape) ) for k in imgs ) )
# new page!
# 48
# new page!
# 24
# ['images/randomVertical/image_1.jpg', 'images/randomVertical/image_2.jpg', 'images/randomVertical/image_3.jpg']

# %% [markdown]
# converting random english images to pdf

# %%
from PIL import Image
from fpdf import FPDF

#pdf = FPDF()
cover = Image.open('images/cover.jpg')
width, height = cover.size
pdf = FPDF(unit = "pt", format = [width, height])
imagelist = ['images/cover.jpg']
    
# imagelist is the list with all image filenames
for x in range(1, len(imageCount)+1):
    imagelist.append(randomVertical + imageName[x])
    

for image in imagelist:
    pdf.add_page()
    pdf.image(image, 0, 0, width, height)
pdf.output("result.pdf", "F")
print("done!")
# Out:
# done!

# %% [markdown]
# creating random hindi vertical and horizontal stripes

# %%
import numpy as np
import PIL
from os import listdir
from os.path import isfile, join

mypath = hindiDialogues
#onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
onlyfiles = []
verticalImage = []
imageCount = []
for i in range(1,74):
    onlyfiles.append(hindiList[i])
i, j = 1, 1
while len(onlyfiles) > 0:
    lines = 0
    print("new page!")
    num_cols = old_num_cols = 0
    print(len(onlyfiles))
    
    while lines < 6 and 0 < len(onlyfiles):
        lines += 1
        while num_cols == old_num_cols:
            num_cols = np.random.randint(3, 6)
        old_num_cols = num_cols
        list_im = onlyfiles[:num_cols]
        imgs = [ PIL.Image.open(k) for k in list_im ]
        
        # pick the image which is the smallest, and resize the others to match it (can be arbitrary image shape here)
        min_shape = sorted( [(np.sum(k.size), k.size ) for k in imgs])[0][1]
        imgs_comb = np.hstack( (np.asarray( k.resize(min_shape) ) for k in imgs ) )
        
        # save that beautiful picture
        imgs_comb = PIL.Image.fromarray( imgs_comb)
        imgs_comb.save( randomHindiHorizontal + imageName[i] ) 
        
        verticalImage.append(randomHindiHorizontal + imageName[i])
        
        #print(window)   
        onlyfiles = onlyfiles[num_cols:]    
        i = i+1
        
    imgs = [ PIL.Image.open(i) for i in verticalImage ]

    # pick the image which is the largest, and resize the others to match it 
    min_shape = sorted( [(np.sum(k.size), k.size ) for k in imgs], reverse = 1)[0][1]
    imgs_comb = np.vstack( (np.asarray( k.resize(min_shape) ) for k in imgs ) )

    # save that beautiful picture
    imgs_comb = PIL.Image.fromarray( imgs_comb)
    imgs_comb.save( randomHindiVertical + imageName[j], width=650, height=1300 )
    imageCount.append(randomHindiVertical + imageName[j])
    j += 1
    verticalImage = verticalImage[len(verticalImage):]
    
print(imageCount)
# Out:
# new page!
# 73
# <ipython-input-18-da046bef5d11>:30: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   imgs_comb = np.hstack( (np.asarray( k.resize(min_shape) ) for k in imgs ) )
# <ipython-input-18-da046bef5d11>:46: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   imgs_comb = np.vstack( (np.asarray( k.resize(min_shape) ) for k in imgs ) )
# new page!
# 49
# new page!
# 23
# ['images/randomHindiVertical/image_1.jpg', 'images/randomHindiVertical/image_2.jpg', 'images/randomHindiVertical/image_3.jpg']

# %% [markdown]
# Converting Hindi images to pdf

# %%
from PIL import Image
from fpdf import FPDF

#pdf = FPDF()
cover = Image.open('images/cover.jpg')
width, height = cover.size
pdf = FPDF(unit = "pt", format = [width, height])
imagelist = ['images/cover.jpg']
    
# imagelist is the list with all image filenames
for x in range(1, len(imageCount)+1):
    imagelist.append(randomHindiVertical + imageName[x])
    

for image in imagelist:
    pdf.add_page()
    pdf.image(image, 0, 0, width, height)
pdf.output("hindiResult.pdf", "F")
print("done!")
# Out:
# done!
